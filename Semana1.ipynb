# %% [markdown]
# <a href="https://colab.research.google.com/github/carolasabatino/pensamiento-computacional-ubaxxi/blob/main/Semana1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejercicio 1

print("Hola mundo!")
# Out:
# Hola mundo!

# %%
#Ejercicio 2

variable = "Hola mundo"
print(variable)
# Out:
# Hola mundo

# %%
#Ejercicio 3

numero = 4
print(numero)
# Out:
# 4

# %%
#Ejercicio 5

primer_numero = 2
segundo_numero = 3

resultado = primer_numero + segundo_numero

print(resultado)
# Out:
# 5

# %%
#Ejercicio 6

primer_numero = 2
segundo_numero = 3

resultado = (primer_numero - segundo_numero) * primer_numero

print(resultado)
# Out:
# -2
