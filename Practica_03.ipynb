# %% [markdown]
# <a href="https://colab.research.google.com/github/carolasabatino/pensamiento-computacional-ubaxxi/blob/main/Practica_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicios de los videos:

# %%
letra = input("Ingrese una letra: ")

def elegir_personaje(letra):
  if letra == 'G':
    print("Guerrero/a")
  elif letra == 'M':
    print("Mago/a")
  elif letra == 'A':
    print("Arquero/a")
  else:
    print("Personaje inválido")

elegir_personaje(letra)
# Out:
# Ingrese una letra: m
# Personaje inválido

# %%
for numero in range(1,5):
  if numero < 3:
    print(f"{numero} - Primer tiempo")
  else:
    print(f"{numero} - Segundo tiempo")
# Out:
# 1 - Primer tiempo
# 2 - Primer tiempo
# 3 - Segundo tiempo
# 4 - Segundo tiempo

# %% [markdown]
# Guía de Ejercicios:

# %%
# 1) Escribir la expresión para saber si un número es más grande que otro.
# Guardarla en una variable de tipo bool e imprimirla por pantalla para ver su valor.

numero_1 = int(input("Ingrese un numero: "))
numero_2 = int(input("Ingrese otro numero: "))

print(f"¿Es {numero_1} más grande que {numero_2}?")

def numero_mas_grande(numero_1, numero_2):
  if numero_1 > numero_2:
    return True
  else:
    return False

numero_mas_grande(numero_1, numero_2)
# Out:
# Ingrese un numero: 4
# Ingrese otro numero: 5
# ¿Es 4 más grande que 5?
# False

# %%
# 2) Repetir el punto anterior, pero con la expresión que determina que una letra NO es vocal.

letra = input("Ingrese una letra: ")

print(f"¿Es {letra} una vocal?")

def es_vocal(letra):
  if letra in ['a', 'e', 'i', 'o', 'u']:
    resultado = True
  else:
    resultado = False
  print(resultado)

es_vocal(letra)
# Out:
# Ingrese una letra: r
# ¿Es r una vocal?
# False

# %%
# 3) Repetir, pero para la expresión que permite saber si un número es par y menor a 10.

numero = int(input("Ingrese un numero: "))

print(f"¿Es {numero} par y menor a 10?")

def par_menor(numero):
  if numero % 2 == 0 and numero < 10:
    return True
  else:
    return False

par_menor(numero)
# Out:
# Ingrese un numero: 44
# ¿Es 44 par y menor a 10?
# False

# %%
# 4. Crear una función que, dado un número, devuelva su valor absoluto.
# El valor absoluto de un número es el mismo número sin considerar el signo.

def valor_absoluto(numero):
  if numero < 0:
    numero = -numero
  else:
    numero = numero
  return numero

valor_absoluto(numero=-4)
# Out:
# 4

# %%
# 5) Crear el programa al que sea imposible ganarle en el juego de “Piedra, papel o tijera”.

print("Piedra (R), Papel (P) o Tijera (T)")
letra = input("Ingrese una letra: ")

if letra == 'R':
  print("Papel. ¡Te gané!")
elif letra == 'P':
  print("Tijera. ¡Te gané!")
elif letra == 'T':
  print("Piedra. ¡Te gané!")
else:
  print("No vale")
# Out:
# Piedra (R), Papel (P) o Tijera (T)
# Ingrese una letra: E
# No vale

# %%
# 6) Escribir código que, dado dos enteros, determine si la suma de ambos da menos que otro entero.

numero1 = int(input("Ingrese un número: "))
numero2 = int(input("Ingrese otro número: "))
limite = int(input("Ingrese el límite: "))

print(f"¿La suma entre {numero1} y {numero2} da más que {limite}?")

if (numero1 + numero2) < limite:
  falta = limite - (numero1 + numero2)
  print(f"Para llegar a {limite} falta {falta}.")
elif (numero1 + numero2) > limite:
  print(f"Llega a {limite}.")
else:
  print("Da justo 100")
# Out:
# Ingrese un número: 40
# Ingrese otro número: 400
# Ingrese el límite: 100
# ¿La suma entre 40 y 400 da más que 100?
# Llega a 100.

# %%
# 7) Crear una función que, dada una letra, imprima por pantalla la estación del año que representa.

def estacion(letra):
  if letra == 'V':
    print("Verano")
  elif letra == 'O':
    print("Otoño")
  elif letra == 'I':
    print("Invierno")
  elif letra == 'P':
    print("Primavera")
  else:
    print("Error")

estacion(letra="I")
# Out:
# Invierno

# %%
# 8) Crear una función que reciba un número entero e imprima por pantalla los números del 1 hasta ese número.

numero = int(input("Ingrese un número: "))

def contar(numero):
  for i in range(1, numero + 1):
    print(i)

contar(numero)
# Out:
# Ingrese un número: 4
# 1
# 2
# 3
# 4

# %%
# 9) Crear una función que reciba un número entero e imprima por pantalla la tabla de ese número del 1 al 10.

numero = int(input("Ingrese un número: "))

def tablas(numero):
  for i in range(1, 11):
    print(i * numero)

tablas(numero)
# Out:
# Ingrese un número: 4
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 40

# %%
# 10) Crear una función que dado un entero imprima “Que los cumplas feliz” esa cantidad de veces.

def cumpleañito(entero):
  for i in range(1, entero + 1):
    print("Que los cumplas feliz")

cumpleañito(entero=4)
# Out:
# Que los cumplas feliz
# Que los cumplas feliz
# Que los cumplas feliz
# Que los cumplas feliz

# %%
# 11)  Crear una función que reciba un número entero que representa lo que hay que cobrar,
# le pida al usuario ingresar un monto, y se vaya mostrando por pantalla cuánto falta para
# completar el pago. Repetir este proceso hasta que la deuda sea 0 o menor.

def cobros(entero):
  monto = int(input("Ingrese el monto que va a pagar: "))
  while monto < entero:
    entero = entero - monto
    print(f"El importe a pagar es de {entero} pesos. Por favor, ingrese un monto.")
    monto = int(input("Ingrese el monto que va a pagar: "))
  print("Completó el pago.")

cobros(entero=100)
# Out:
# Ingrese el monto que va a pagar: 80
# El importe a pagar es de 20 pesos. Por favor, ingrese un monto.
# Ingrese el monto que va a pagar: 2
# El importe a pagar es de 18 pesos. Por favor, ingrese un monto.
# Ingrese el monto que va a pagar: 8
# El importe a pagar es de 10 pesos. Por favor, ingrese un monto.
# Ingrese el monto que va a pagar: 10
# Completó el pago.

# %%
# 12) Escribir código que recorra los números del 1 al 20 y determine para cada uno si es par o impar.

for i in range(1, 21):
  if i % 2 == 0:
    print(f"El número {i} es par")
  else:
    print(f"El número {i} es impar")
# Out:
# El número 1 es impar
# El número 2 es par
# El número 3 es impar
# El número 4 es par
# El número 5 es impar
# El número 6 es par
# El número 7 es impar
# El número 8 es par
# El número 9 es impar
# El número 10 es par
# El número 11 es impar
# El número 12 es par
# El número 13 es impar
# El número 14 es par
# El número 15 es impar
# El número 16 es par
# El número 17 es impar
# El número 18 es par
# El número 19 es impar
# El número 20 es par

# %% [markdown]
# 13. Se tiene una máquina de sacar juguetes que funciona cuando se ingresa una
# determinada cantidad de fichas, y se quiere hacer una función que imite ese
# comportamiento.
#
# a. Hacer una función que reciba un número que represente el precio de la
# máquina, e imprima por pantalla “Ingresá x fichas para comenzar” hasta que
# se hayan ingresado esa cantidad de letras F (que representan una ficha), y
# luego “¡A jugar!” cuando se hayan ingresado todas las fichas necesarias. ATENCIÓN: notar cómo cuando se ingresa una letra distinta de F, esta se ignora a
# la hora de contar la cantidad de fichas que fueron ingresadas.
#
# b. Ahora se quiere que se vaya mostrando por pantalla, cuántas fichas FALTAN
# ingresar para empezar a jugar.
#
# c. Agregar a la función el mensaje de error “Por favor solamente ingrese fichas
# reales (F)” cuando se recibe una letra distinta de F.

# %%
def juego(cantidad_de_fichas):
  while(cantidad_de_fichas > 0):
    print(f"Ingresa {cantidad_de_fichas} fichas F para comenzar.")
    ficha_ingresada = input()
    if ficha_ingresada == 'F':
      cantidad_de_fichas = cantidad_de_fichas - 1
    else:
      cantidad_de_fichas = cantidad_de_fichas
      print("Por favor solamente ingrese fichas reales (F)")
  print("¡A jugar!")

juego(cantidad_de_fichas=3)
# Out:
# Ingresa 3 fichas para comenzar.
# F
# Ingresa 2 fichas para comenzar.
# H
# Por favor solamente ingrese fichas reales (F)
# Ingresa 2 fichas para comenzar.
# F
# Ingresa 1 fichas para comenzar.
# F
# ¡A jugar!

# %% [markdown]
# 14. Crear una función que reciba un número entero e imprima los números primos entre 0 y el número ingresado.
# AYUDA: un número es primo cuando solamente es divisible por sí mismo y por 1, es
# decir que para ver si es primo hay que ver que el módulo (%) de ese número con los anteriores hasta el 1 (sin incluirlo) sea distinto de 0, o sea que no sea divisible.

# %%
def numeros_primos(entero):
    for numero in range(2, entero + 1):
      divisores = 0
      for i in range(1, numero + 1):
          if numero % i == 0:
              divisores += 1
      if divisores == 2:
        print(numero)

numeros_primos(entero=10)
# Out:
# 2
# 3
# 5
# 7
